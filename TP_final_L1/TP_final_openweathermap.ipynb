# %% [markdown]
# Execute this file from colab <br>
# url: https://colab.research.google.com/drive/14L0sV1SkxOf2uRDgQaINKCNW8KjkeLBy#scrollTo=4ROs8-AwKJb1

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount("/content/drive")
#
# ModuleNotFoundError: No module named 'google'

# %%
# %cd /content/drive
# %ls -lah

# %%
# %pwd

# %% [markdown]
# # important 👇
#  - At https://drive.google.com/drive/shared-with-me
#   - You have to drag the folder. "TP_final_openweathermap_nivel_inicial" <br>
#       <b>to the "My Drive" folder</b>
#
# The project now works in 'colab'.

# %%
# %ls -lah /content/drive/MyDrive/TP_final_openweathermap_nivel_inicial/

# %%
# %cd /content/drive/MyDrive/TP_final_openweathermap_nivel_inicial

# %%
# %pwd

# %%
# %ls -lah

# %%
from api_key_utils import api_key_utils
from get_weather_data import get_weather_data
from process_weather_data import process_weather_data
from normalize_data import normalize_data


def main():
    # Obtain API key
    api_key = api_key_utils()

    # Define a list of coordinates of cities you wish to consult.
    coords_list = [
        (-27.46056, -58.983891),   # Resistencia, AR
        (51.512791, -0.09184),     # City of London, GB
        (40.714272, -74.005966),   # New York, US
        (37.90448, -4.77768),      # Cordoba, ES
        (25.025881, 121.651611),   # Taipei, TW
        (-34.599998, -58.450001),  # Ciudad Autónoma de Buenos Aires, AR
        (19.428471, -99.127663),   # Mexico City, MX
        (53.355122, -6.24922),     # Dublin City, IE (Ireland)
        (41.694111, 44.833679),    # Tbilisi, GE (Georgia)
        (4.60971, -74.081749),     # Bogotá, CO
        (35.689499, 139.691711)    # Tokyo, JP
    ]

    # Call the get_weather_data() function with the list of coordinates and the API key.
    weather_data_list = get_weather_data(coords_list, api_key)
    # print("Complet JSON:", weather_data_list)

    if weather_data_list:
        # call the function
        processed_data = process_weather_data(weather_data_list)
        print("JSON filtrado:\n", processed_data)
        print("--------------------------------")

        # call the method that creates the csv
        normaliz%Y-%m-%d'e_data(processed_data)


if __name__ == '__main__':
    main()
# Out:
# JSON filtrado:
#  [{'city': 'Resistencia', 'temp': 18.87, 'description': 'clear sky', 'temp_min': 18.36, 'temp_max': 19.03, 'my_timezone': -3.0, 'sunrise_local': '07:29:15', 'sunset_local': '18:32:58', 'dt_local_datetime': datetime.datetime(2023, 8, 12, 17, 55, 37), 'dt_colab': '2023-08-12T14:55:37'}, {'city': 'City of London', 'temp': 17.86, 'description': 'broken clouds', 'temp_min': 16.14, 'temp_max': 18.88, 'my_timezone': 1.0, 'sunrise_local': '01:40:31', 'sunset_local': '16:30:36', 'dt_local_datetime': datetime.datetime(2023, 8, 12, 17, 57, 44), 'dt_colab': '2023-08-12T14:57:44'}, {'city': 'New York', 'temp': 27.75, 'description': 'scattered clouds', 'temp_min': 24.96, 'temp_max': 31.3, 'my_timezone': -4.0, 'sunrise_local': '07:03:11', 'sunset_local': '20:59:11', 'dt_local_datetime': datetime.datetime(2023, 8, 12, 17, 50, 52), 'dt_colab': '2023-08-12T14:50:52'}, {'city': 'Cordoba', 'temp': 34.57, 'description': 'clear sky', 'temp_min': 34.57, 'temp_max': 34.57, 'my_timezone': 2.0, 'sunrise_local': '02:31:28', 'sunset_local': '16:17:08', 'dt_local_datetime': datetime.datetime(2023, 8, 12, 18, 0, 33), 'dt_colab': '2023-08-12T15:00:33'}, {'city': 'Taipei', 'temp': 25.5, 'description': 'few clouds', 'temp_min': 24.01, 'temp_max': 28.15, 'my_timezone': 8.0, 'sunrise_local': '18:26:11', 'sunset_local': '07:30:47', 'dt_local_datetime': datetime.datetime(2023, 8, 12, 18, 0, 34), 'dt_colab': '2023-08-12T15:00:34'}, {'city': 'Buenos Aires F.D.', 'temp': 11.21, 'description': 'smoke', 'temp_min': 10.6, 'temp_max': 11.94, 'my_timezone': -3.0, 'sunrise_local': '07:37:22', 'sunset_local': '18:20:33', 'dt_local_datetime': datetime.datetime(2023, 8, 12, 17, 59, 1), 'dt_colab': '2023-08-12T14:59:01'}, {'city': 'Mexico City', 'temp': 24.94, 'description': 'few clouds', 'temp_min': 24.94, 'temp_max': 24.94, 'my_timezone': -6.0, 'sunrise_local': '09:16:21', 'sunset_local': '22:07:01', 'dt_local_datetime': datetime.datetime(2023, 8, 12, 17, 54, 12), 'dt_colab': '2023-08-12T14:54:12'}, {'city': 'Dublin City', 'temp': 16.48, 'description': 'scattered clouds', 'temp_min': 16.09, 'temp_max': 16.91, 'my_timezone': 1.0, 'sunrise_local': '01:59:10', 'sunset_local': '17:01:12', 'dt_local_datetime': datetime.datetime(2023, 8, 12, 17, 59, 43), 'dt_colab': '2023-08-12T14:59:43'}, {'city': 'Tbilisi', 'temp': 27.84, 'description': 'clear sky', 'temp_min': 27.84, 'temp_max': 27.84, 'my_timezone': 4.0, 'sunrise_local': '23:06:32', 'sunset_local': '13:04:55', 'dt_local_datetime': datetime.datetime(2023, 8, 12, 18, 0, 3), 'dt_colab': '2023-08-12T15:00:03'}, {'city': 'Bogota', 'temp': 17.73, 'description': 'scattered clouds', 'temp_min': 17.73, 'temp_max': 17.73, 'my_timezone': -5.0, 'sunrise_local': '07:53:05', 'sunset_local': '20:09:53', 'dt_local_datetime': datetime.datetime(2023, 8, 12, 17, 58, 14), 'dt_colab': '2023-08-12T14:58:14'}, {'city': 'Tokyo', 'temp': 26.31, 'description': 'broken clouds', 'temp_min': 25.34, 'temp_max': 27.1, 'my_timezone': 9.0, 'sunrise_local': '16:58:00', 'sunset_local': '06:34:39', 'dt_local_datetime': datetime.datetime(2023, 8, 12, 18, 0, 1), 'dt_colab': '2023-08-12T15:00:01'}]
# --------------------------------
